# %%
import pandas as pd
import numpy as np
import csv

# %%
data = pd.read_csv('data/634629.csv')

# %%
data.head(3)
# Out:
#                 STATION STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 1471  GHCND:EZM00011406      CHEB EZ        490    50.067     12.383
# 1477  GHCND:EZM00011406      CHEB EZ        490    50.067     12.383
# 1478  GHCND:EZM00011406      CHEB EZ        490    50.067     12.383
#
#           DATE  SNWD Measurement Flag Quality Flag Source Flag  \
# 1471  19730110    10                                         S
# 1477  19730116    41                                         S
# 1478  19730117    79                                         S
#
#               ...           TMAX  Measurement Flag.1 Quality Flag.1  \
# 1471          ...              0
# 1477          ...            -10
# 1478          ...            -20
#
#      Source Flag.1 Time of Observation.1  TMIN  Measurement Flag.2  \
# 1471             S                  9999   -30
# 1477             S                  9999   -30
# 1478             S                  9999   -40
#
# ...

# %%
data = data[data.SNWD >= 0]

# %%
data['datum'] = data.DATE.apply(lambda x: str(x)[0:4] + '-' + str(x)[4:6] + '-' + str(x)[6:8])

# %%
data.datum = pd.to_datetime(data.datum)

# %%
with open('data/first_snow.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=';', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow(['date', 'station', 'snowdepth_mm'])
    for year in range(1970, 2015):
        dat = data[(data.datum >= str(year) + '-09-15') & (data.datum <= str(year + 1) + '-03-31')]
        if (len(dat) > 0):
            dat.sort('datum', inplace=True)
            spamwriter.writerow([str(dat.datum.iloc[0]), str(dat.STATION_NAME.iloc[0]), str(dat.SNWD.iloc[0])])
        else:
            continue
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py:2915: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   inplace=inplace, kind=kind, na_position=na_position)

# %%
data.sort('datum', inplace=True)

# %%
data[data.datum >= '1982-01-01']
# Out:
#                   STATION    STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 21490   GHCND:EZM00011659    PRIBYSLAV EZ      536.4   49.5830    15.7670
# 4644    GHCND:EZM00011406         CHEB EZ      490.0   50.0670    12.3830
# 264929  GHCND:EZM00011723       TURANY EZ      237.1   49.1510    16.6940
# 214956  GHCND:EZ000011464    MILESOVKA EZ      833.0   50.5544    13.9314
# 166903  GHCND:EZM00011520  PRAHA LIBUS EZ      303.7   50.0000    14.4500
# 246723  GHCND:EZM00011603      LIBEREC EZ      401.5   50.7670    15.0170
# 125557  GHCND:EZM00011518       RUZYNE EZ      380.1   50.1010    14.2600
# 264930  GHCND:EZM00011723       TURANY EZ      237.1   49.1510    16.6940
# 21491   GHCND:EZM00011659    PRIBYSLAV EZ      536.4   49.5830    15.7670
# 246724  GHCND:EZM00011603      LIBEREC EZ      401.5   50.7670    15.0170
# 4645    GHCND:EZM00011406         CHEB EZ      490.0   50.0670    12.3830
# 230031  GHCND:EZM00011787    LYSA HORA EZ     1326.8   49.5500    18.4500
# ...
